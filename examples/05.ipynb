# %% [markdown]
# ### Croston's Model

# %%
import pandas as pd
import os
os.chdir(os.path.expanduser(".."))
import tslib
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./data/daily_min_temp.csv")

# %%
from tslib import models

# %%
from statsforecast.utils import ConformalIntervals

# %%
m = models.CrostonModel(prediction_intervals=ConformalIntervals())

# %%
m = m.fit(ts=df.Temp)

# %%
m.forecast(steps=3)
# Out:
# array([13.83247268, 13.83247268, 13.83247268])

# %%
m.residual_analysis()

# %%
#m.summary()

# %%
m.plot_fit()

# %%
m.get_fit_interval()
# Out:
#       lower_bound  upper_bound
# 0             NaN          NaN
# 1       15.562280    25.837720
# 2       15.282280    25.557720
# 3       14.404280    24.679720
# 4       12.921680    23.197120
# ...           ...          ...
# 3645     8.208580    18.484021
# 3646     8.404690    18.680131
# 3647     8.421967    18.697408
# 3648     8.404061    18.679501
# 3649     9.051526    19.326967
#
# [3650 rows x 2 columns]

# %%
m.get_forecast_interval()
# Out:
#    lower_bound  upper_bound
# 0    11.746927    15.918019
# 1    11.746927    15.918019
# 2    11.746927    15.918019
# 3    11.746927    15.918019
# 4    11.746927    15.918019
